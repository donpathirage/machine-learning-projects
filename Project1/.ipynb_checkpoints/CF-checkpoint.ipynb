# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# Get Dataset

df = pd.read_excel('proj1Dataset.xlsx')  #read into dataframe
df.head()

x = np.array(df['Weight'])        #Predictor array
t = np.array(df['Horsepower'])    #Target array

emptyidx = np.argwhere(np.isnan(t))  #Clean up data
t = t[~np.isnan(t)]
x = np.delete(x, emptyidx)

x = np.reshape(x, (len(x),1))
t = np.reshape(t,(len(t),1))

# Normalize and Plot Data
x2 = x/np.std(x)
plt.scatter(x,t)

# %%
# Create Design Matrix

X = np.ones((len(x),1))
X = np.mat(np.hstack((x2,X)))
T = np.mat(t)

# Closed Form Solution
    
weights = np.dot(np.dot(np.linalg.inv(np.dot(X.T,X)),X.T),t)

# %%
# Plot Closed Form Solution
weights = CFS(X,T)
print(weights)
plt.figure()
plt.scatter(x2,t)
plt.plot(x2,np.dot(X,weights),color = 'orange')
plt.title("Closed Form Solution")
plt.show()
# Out:
# [[ 33.55446801]
#  [-13.04012986]]
